# %% [markdown]
# <a href="https://colab.research.google.com/github/malvikabatish-g/PythonPractice/blob/main/ShriRamColab1CDACPythonLecture4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# function

def greet(name):#nam eis parameter
    """This function greets a person passed in as a parameter"""
    print("Hello,"+name+".Good morning!")

greet('Malvika')
# Out:
# Hello,Malvika.Good morning!

# %%
greet('Malvika') # value passed is= argument for parameter name
# Out:
# Hello,Malvika.Good morning!

# %%
def square(num):
     """this function returns square of a number"""

     return num**2

print (square(5))
print (square.__doc__)## double underscore to return docstring _ _doc_ _
# Out:
# 25
# this function returns square of a number

# %%
def greetdef(name, age):
  print (name,age)

greetdef('Malvika',44)
greetdef(name='Riya',age=23)
# Out:
# Malvika 44
# Riya 23

# %%
# factorial
def fact(num):
  if num==1:
    return 1
  else:
    return num*fact(num-1)


fact(5)
# Out:
# 120

# %%
def add(a,b):
  """return statement demo"""
  return(a+b)
print(add(1,2))
# Out:
# 3

# %%
# lambda function
lambda x: x*2

sq = lambda x: x*x
print (sq(5))
# Out:
# 25

# %%
format = lambda obj, category: 'the "%s" is a "%s"' % (obj, category)
print(format('fir','conifer'))
# Out:
# the "fir" is a "conifer"

# %%
#use case for map()

num=[1,2,3,4,5]
output =list(map(lambda x:x*2, num) )
print(output)


#use case for filter()
result= list(filter(lambda x:x %2==0, num))
print (result)

# sorted()
data=[(1,3),(2,1),(4,2)]
dict1={1:2,3:1,0:5}
sd =sorted(dict1.items(),key=lambda x:x[1])
print(sd)
# Out:
# [2, 4, 6, 8, 10]
# [2, 4]
# [(3, 1), (1, 2), (0, 5)]

# %%
#use case for map()

num=[1,2,3,4,5]
output =list(map(lambda x:x*2, num) )
print(output)


#use case for filter()
result= list(filter(lambda x:x %2==0, num))
print (result)

# sorted()
data=[(1,3),(2,1),(4,2)]
dict1={1:2,3:1,0:5}
sd =sorted(dict1.items(),key=lambda item: item[1]) # Changed to sort by value
print(sd)
# Out:
# [2, 4, 6, 8, 10]
# [2, 4]
# [(3, 1), (1, 2), (0, 5)]
